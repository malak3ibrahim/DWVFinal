# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, PowerTransformer
from scipy import stats

# %%
df = pd.read_csv("global_edu_insights.csv")

# %%
df
# Out:
#            Country  Year      Region  GDP_per_capita  Education_Expenditure  \
# 0            India  2015  South Asia        18973.71                   4.29
# 1          Nigeria  2018      Africa         5935.70                   2.00
# 2            Egypt  2017      Africa         -355.06                   4.67
# 3            India  2023  South Asia        16670.91                   2.00
# 4          Germany  2024      Europe        17748.95                   2.00
# ...            ...   ...         ...             ...                    ...
# 9995         Kenya  2016      Africa         1396.31                   4.19
# 9996     Australia  2021     Oceania        15932.28                   7.11
# 9997         India  2017  South Asia         5290.88                   3.20
# 9998  South Africa  2022      Africa         8726.83                   2.18
# 9999         Kenya  2015      Africa         4494.53                   4.20
#
#       Primary_Enrollment  Secondary_Enrollment  Tertiary_Enrollment  \
# 0                   98.2                  90.2                 31.5
# 1                   86.4                  69.4                 19.8
# 2                   89.2                  78.8                 26.0
# 3                   88.4                  77.0                 46.1
# 4                   96.6                  71.1                 24.8
# ...                  ...                   ...                  ...
# 9995                89.3                  65.5                 38.2
# 9996                83.0                  78.5                 29.2
# 9997                97.4                  76.9                 20.3
# 9998                85.9                  83.3                 51.9
# 9999               100.0                  78.6                 43.5
#
#       Literacy_Rate  Avg_Years_Schooling  Internet_Access  \
# 0              82.7                 12.7             75.3
# 1              88.1                  7.7             31.8
# 2              82.1                  8.3             97.0
# 3              86.7                  9.3             54.0
# 4              91.1                 11.6             78.6
# ...             ...                  ...              ...
# 9995           72.2                  9.4             59.2
# 9996           88.4                 10.2             76.7
# 9997           72.0                  9.7             55.7
# 9998           91.0                  7.8             88.8
# 9999           85.3                  7.0             41.8
#
#       Pupil_Teacher_Ratio  Gender_Parity_Index  Unemployment_Rate  \
# 0                    17.7                 1.05                5.6
# 1                    27.3                 0.98                7.2
# 2                    19.9                 0.89                9.5
# 3                    12.6                 0.93                5.6
# 4                    15.8                 0.97                8.0
# ...                   ...                  ...                ...
# 9995                 22.9                 1.10                8.5
# 9996                 23.7                 1.02                3.5
# 9997                 17.3                 1.07                6.9
# 9998                 22.7                 1.10                9.1
# 9999                 19.7                 0.82                5.2
#
#       Government_Policy_Score
# 0                         5.1
# 1                         3.2
# 2                         3.6
# 3                         8.1
# 4                         8.0
# ...                       ...
# 9995                     10.0
# 9996                      7.2
# 9997                      8.0
# 9998                      5.2
# 9999                      6.5
#
# [10000 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  10000 non-null  object
#  1   Year                     10000 non-null  int64
#  2   Region                   10000 non-null  object
#  3   GDP_per_capita           10000 non-null  float64
#  4   Education_Expenditure    10000 non-null  float64
#  5   Primary_Enrollment       10000 non-null  float64
#  6   Secondary_Enrollment     10000 non-null  float64
#  7   Tertiary_Enrollment      10000 non-null  float64
#  8   Literacy_Rate            10000 non-null  float64
#  9   Avg_Years_Schooling      10000 non-null  float64
#  10  Internet_Access          10000 non-null  float64
#  11  Pupil_Teacher_Ratio      10000 non-null  float64
#  12  Gender_Parity_Index      10000 non-null  float64
#  13  Unemployment_Rate        10000 non-null  float64
#  14  Government_Policy_Score  10000 non-null  float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#               Year  GDP_per_capita  Education_Expenditure  Primary_Enrollment  \
# count  10000.00000    10000.000000           10000.000000        10000.000000
# mean    2019.51200    12926.395549               4.512214           94.596210
# std        2.86794     9125.852740               1.415395            4.333091
# min     2015.00000   -27520.070000               2.000000           75.400000
# 25%     2017.00000     7008.902500               3.477500           91.700000
# 50%     2020.00000    13220.905000               4.480000           95.000000
# 75%     2022.00000    19040.337500               5.490000           98.400000
# max     2024.00000    43844.730000               8.000000          100.000000
#
#        Secondary_Enrollment  Tertiary_Enrollment  Literacy_Rate  \
# count          10000.000000         10000.000000   10000.000000
# mean              74.859780            35.213050      84.776670
# std                9.920045            14.655766       9.428202
# min               37.900000             5.000000      50.000000
# 25%               68.100000            25.000000      78.300000
# 50%               74.900000            35.100000      85.100000
# 75%               81.700000            44.900000      91.700000
# max              100.000000            90.400000     100.000000
#
#        Avg_Years_Schooling  Internet_Access  Pupil_Teacher_Ratio  \
# count         10000.000000     10000.000000         10000.000000
# mean              9.507320        60.070310            20.095360
# std               2.015383        19.412294             4.871982
# min               3.000000        10.000000            10.000000
# 25%               8.200000        46.600000            16.700000
# 50%               9.500000        60.400000            20.100000
# 75%              10.900000        73.700000            23.400000
# max              15.000000       100.000000            38.600000
#
#        Gender_Parity_Index  Unemployment_Rate  Government_Policy_Score
# count         10000.000000       10000.000000             10000.000000
# mean              0.998661           7.050090                 5.989390
# std               0.095864           2.967915                 1.957721
# min               0.800000           1.000000                 0.000000
# 25%               0.930000           5.000000                 4.700000
# 50%               1.000000           7.000000                 6.000000
# 75%               1.070000           9.100000                 7.300000
# max               1.200000          18.300000                10.000000

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Country                    0
# Year                       0
# Region                     0
# GDP_per_capita             0
# Education_Expenditure      0
# Primary_Enrollment         0
# Secondary_Enrollment       0
# Tertiary_Enrollment        0
# Literacy_Rate              0
# Avg_Years_Schooling        0
# Internet_Access            0
# Pupil_Teacher_Ratio        0
# Gender_Parity_Index        0
# Unemployment_Rate          0
# Government_Policy_Score    0
# dtype: int64

# %%
# Display the number of duplicate rows
duplicate_rows = df.duplicated().sum()
print(f'No. of Duplicate rows: {duplicate_rows}')
# Out:
# No. of Duplicate rows: 0

# %%
#Display the number of unique values in each column
unique_values = df.nunique()
print(unique_values)
# Out:
# Country                      20
# Year                         10
# Region                        9
# GDP_per_capita             9987
# Education_Expenditure       595
# Primary_Enrollment          209
# Secondary_Enrollment        535
# Tertiary_Enrollment         717
# Literacy_Rate               442
# Avg_Years_Schooling         119
# Internet_Access             875
# Pupil_Teacher_Ratio         250
# Gender_Parity_Index          41
# Unemployment_Rate           161
# Government_Policy_Score     101
# dtype: int64

# %%
df.head()
# Out:
#    Country  Year      Region  GDP_per_capita  Education_Expenditure  \
# 0    India  2015  South Asia        18973.71                   4.29
# 1  Nigeria  2018      Africa         5935.70                   2.00
# 2    Egypt  2017      Africa         -355.06                   4.67
# 3    India  2023  South Asia        16670.91                   2.00
# 4  Germany  2024      Europe        17748.95                   2.00
#
#    Primary_Enrollment  Secondary_Enrollment  Tertiary_Enrollment  \
# 0                98.2                  90.2                 31.5
# 1                86.4                  69.4                 19.8
# 2                89.2                  78.8                 26.0
# 3                88.4                  77.0                 46.1
# 4                96.6                  71.1                 24.8
#
#    Literacy_Rate  Avg_Years_Schooling  Internet_Access  Pupil_Teacher_Ratio  \
# 0           82.7                 12.7             75.3                 17.7
# 1           88.1                  7.7             31.8                 27.3
# 2           82.1                  8.3             97.0                 19.9
# 3           86.7                  9.3             54.0                 12.6
# 4           91.1                 11.6             78.6                 15.8
#
#    Gender_Parity_Index  Unemployment_Rate  Government_Policy_Score
# 0                 1.05                5.6                      5.1
# 1                 0.98                7.2                      3.2
# 2                 0.89                9.5                      3.6
# 3                 0.93                5.6                      8.1
# 4                 0.97                8.0                      8.0

# %%
# Calculate Q1 and Q3
Q1 = df['Literacy_Rate'].quantile(0.25)
Q3 = df['Literacy_Rate'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out outliers
outliers = df[(df['Literacy_Rate'] < lower_bound) | (df['Literacy_Rate'] > upper_bound)]

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"\nOutliers in '{col}':")
    print(outliers[[col]])
# Out:
# Outliers in 'Year':
# Empty DataFrame
# Columns: [Year]
# Index: []
#
# Outliers in 'GDP_per_capita':
#       GDP_per_capita
# 333        -12622.49
# 457        -15074.45
# 490        -15229.35
# 568        -11716.29
# 656         37921.70
# ...              ...
# 9659       -19777.56
# 9750       -11666.94
# 9788       -16404.06
# 9941       -12535.62
# 9975       -11910.68
#
# [96 rows x 1 columns]
#
# Outliers in 'Education_Expenditure':
# Empty DataFrame
# Columns: [Education_Expenditure]
# Index: []
#
# Outliers in 'Primary_Enrollment':
#       Primary_Enrollment
# 470                 80.8
# 516                 81.4
# 543                 81.5
# 814                 75.4
# 897                 79.9
# 952                 78.4
# 1221                78.7
# 1491                80.0
# 1670                81.6
# 1863                78.5
# 2258                79.7
# 2399                77.7
# 2466                77.9
# 2501                79.5
# 2681                80.6
# 2859                78.9
# 3346                80.5
# 3353                79.7
# 4276                78.4
# 5170                81.6
# 5456                81.0
# 5853                79.9
# 6146                81.4
# 6503                79.4
# 7011                80.9
# 7465                81.3
# 7955                80.2
# 8190                81.3
# 8609                80.4
# 9256                81.3
# 9830                80.1
# 9973                79.6
#
# Outliers in 'Secondary_Enrollment':
#       Secondary_Enrollment
# 128                   46.3
# 164                   45.6
# 386                   45.9
# 398                   43.2
# 492                   46.0
# 634                   38.1
# 690                   45.6
# 970                   45.3
# 1226                  46.8
# 1361                  47.5
# 1887                  46.2
# 2562                  41.6
# 2649                  45.8
# 2801                  45.5
# 2936                  44.2
# 3183                  47.5
# 3196                  47.4
# 3610                  41.1
# 3826                  47.2
# 4302                  46.0
# 4401                  46.3
# 4408                  40.8
# 4411                  46.6
# 4744                  43.1
# 4962                  43.0
# 5056                  45.9
# 5298                  46.8
# 6991                  43.5
# 7017                  45.1
# 7529                  45.1
# 7946                  37.9
# 8081                  45.5
# 8141                  46.5
# 8323                  42.5
# 8641                  41.9
# 9555                  40.8
# 9639                  46.8
# 9851                  47.0
#
# Outliers in 'Tertiary_Enrollment':
#       Tertiary_Enrollment
# 435                  79.0
# 591                  75.7
# 635                  75.8
# 687                  85.7
# 955                  84.3
# 1120                 82.8
# 1162                 76.0
# 1267                 75.5
# 1448                 81.1
# 2379                 90.4
# 2461                 77.8
# 2997                 80.3
# 3209                 76.1
# 3278                 78.9
# 3332                 75.7
# 4763                 87.1
# 5182                 75.8
# 5193                 80.0
# 5213                 75.8
# 5219                 77.3
# 5374                 75.9
# 5603                 82.5
# 5774                 80.1
# 5851                 80.2
# 6047                 75.0
# 6050                 76.5
# 6218                 76.1
# 6403                 74.9
# 6629                 75.2
# 6879                 77.2
# 6983                 85.8
# 6996                 75.4
# 7225                 75.2
# 7491                 75.0
# 7492                 80.6
# 7670                 88.9
# 7684                 81.1
# 7915                 76.8
# 8048                 74.8
# 8248                 81.2
# 8979                 82.7
# 9109                 77.0
# 9469                 77.4
# 9604                 77.3
# 9844                 78.5
#
# Outliers in 'Literacy_Rate':
#       Literacy_Rate
# 88             56.5
# 251            56.7
# 851            57.6
# 935            57.3
# 997            57.9
# 1615           55.9
# 1731           56.9
# 2911           52.5
# 3515           57.8
# 3562           55.2
# 3594           50.0
# 3846           56.6
# 3925           55.7
# 3941           55.3
# 3992           57.7
# 4017           52.5
# 4472           50.9
# 4517           56.2
# 4609           56.9
# 4614           50.8
# 4834           56.0
# 5825           57.1
# 5834           54.5
# 5860           56.6
# 5874           54.3
# 6066           57.0
# 6162           56.5
# 6389           55.7
# 6991           55.5
# 7514           56.9
# 7876           57.8
# 7933           57.0
# 8754           57.5
# 9086           53.8
# 9099           53.8
# 9208           55.4
# 9407           53.7
# 9545           54.1
# 9594           55.5
# 9712           53.0
#
# Outliers in 'Avg_Years_Schooling':
#       Avg_Years_Schooling
# 561                  15.0
# 607                   3.6
# 771                  15.0
# 800                   3.9
# 1100                 15.0
# ...                   ...
# 9517                 15.0
# 9559                  4.1
# 9742                 15.0
# 9761                 15.0
# 9862                 15.0
#
# [71 rows x 1 columns]
#
# Outliers in 'Internet_Access':
# Empty DataFrame
# Columns: [Internet_Access]
# Index: []
#
# Outliers in 'Pupil_Teacher_Ratio':
#       Pupil_Teacher_Ratio
# 309                  36.2
# 398                  33.8
# 644                  33.6
# 1242                 35.7
# 1801                 38.1
# 2326                 34.4
# 2529                 33.5
# 2717                 36.3
# 2776                 38.6
# 3601                 33.6
# 3876                 33.6
# 4672                 36.2
# 4963                 33.7
# 5142                 34.2
# 5161                 37.2
# 6502                 35.9
# 7599                 36.5
# 7718                 33.6
# 7748                 34.9
# 8426                 34.4
# 8939                 34.2
# 9116                 33.6
# 9591                 33.9
# 9959                 35.2
#
# Outliers in 'Gender_Parity_Index':
# Empty DataFrame
# Columns: [Gender_Parity_Index]
# Index: []
#
# Outliers in 'Unemployment_Rate':
#       Unemployment_Rate
# 39                 16.2
# 208                15.8
# 331                16.5
# 405                16.2
# 610                15.8
# 944                17.1
# 1534               15.5
# 2242               16.5
# 2315               15.3
# 2416               17.1
# 2438               15.6
# 2695               15.7
# 3319               16.9
# 3423               16.0
# 3565               16.6
# 3756               15.9
# 3970               15.9
# 4610               16.6
# 4730               15.4
# 4810               15.6
# 5160               17.2
# 5349               16.1
# 5573               17.3
# 5906               15.7
# 7155               15.4
# 7467               15.9
# 7471               15.4
# 8100               16.2
# 8184               15.9
# 9263               15.6
# 9331               16.8
# 9609               18.3
# 9990               17.2
#
# Outliers in 'Government_Policy_Score':
#       Government_Policy_Score
# 112                       0.8
# 535                       0.8
# 843                       0.6
# 973                       0.4
# 978                       0.0
# 1076                      0.8
# 1149                      0.8
# 1193                      0.8
# 1272                      0.1
# 1478                      0.5
# 1509                      0.0
# 2050                      0.0
# 2449                      0.0
# 2722                      0.0
# 2901                      0.5
# 2958                      0.1
# 2973                      0.7
# 3293                      0.2
# 3746                      0.7
# 3868                      0.7
# 3899                      0.7
# 4066                      0.6
# 4410                      0.0
# 4465                      0.0
# 4473                      0.8
# 4616                      0.0
# 4717                      0.6
# 4979                      0.0
# 5064                      0.2
# 5161                      0.7
# 5631                      0.4
# 5979                      0.1
# 6493                      0.6
# 6791                      0.1
# 7155                      0.0
# 7505                      0.8
# 7575                      0.3
# 7647                      0.7
# 8058                      0.2
# 8096                      0.8
# 8334                      0.0
# 8548                      0.7
# 8871                      0.8
# 9116                      0.2
# 9136                      0.0
# 9209                      0.8
# 9529                      0.2
# 9552                      0.8
# 9733                      0.0
# 9746                      0.0
# 9809                      0.0

# %%
# Function to winsorize a column
def winsorize_column(df, column, lower_quantile=0.05, upper_quantile=0.95):
    q_low = df[column].quantile(lower_quantile)
    q_high = df[column].quantile(upper_quantile)
    df[column + '_winsorized'] = np.where(df[column] < q_low, q_low,
                                          np.where(df[column] > q_high, q_high, df[column]))
    return df

# List of columns with outliers (based on your results)
columns_to_winsorize = [
    'GDP_per_capita',
    'Primary_Enrollment',
    'Secondary_Enrollment',
    'Tertiary_Enrollment',
    'Literacy_Rate',
    'Avg_Years_Schooling',
    'Pupil_Teacher_Ratio',
    'Unemployment_Rate',
    'Government_Policy_Score'
]

# Apply winsorization to each column
for col in columns_to_winsorize:
    df = winsorize_column(df, col)

# %%
# Add 1 to avoid log(0)
df['GDP_per_capita_log'] = np.log1p(df['GDP_per_capita_winsorized'])
# Out:
# C:\Users\malak\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Region_encoded'] = le.fit_transform(df['Region'])

# %%
df.to_csv("global_edu_insights_cleaned.csv", index=False)

# %%
print(df.columns.tolist())
# Out:
# ['Country', 'Year', 'Region', 'GDP_per_capita', 'Education_Expenditure', 'Primary_Enrollment', 'Secondary_Enrollment', 'Tertiary_Enrollment', 'Literacy_Rate', 'Avg_Years_Schooling', 'Internet_Access', 'Pupil_Teacher_Ratio', 'Gender_Parity_Index', 'Unemployment_Rate', 'Government_Policy_Score', 'GDP_per_capita_winsorized', 'Primary_Enrollment_winsorized', 'Secondary_Enrollment_winsorized', 'Tertiary_Enrollment_winsorized', 'Literacy_Rate_winsorized', 'Avg_Years_Schooling_winsorized', 'Pupil_Teacher_Ratio_winsorized', 'Unemployment_Rate_winsorized', 'Government_Policy_Score_winsorized', 'GDP_per_capita_log', 'Region_encoded']

# %%
#Average metrics per region
region_avg = df.groupby('Region')[
    ['GDP_per_capita_winsorized', 'Literacy_Rate_winsorized', 'Unemployment_Rate_winsorized']
].mean().reset_index()

# %%
# Save region-wise average metrics
region_avg.to_csv('region_avg_metrics.csv', index=False)

# %%
#Melting
#Compare all enrollment types over years
enrollment = df[['Year', 'Primary_Enrollment_winsorized', 'Secondary_Enrollment_winsorized', 'Tertiary_Enrollment_winsorized']]
enrollment_melted = enrollment.melt(id_vars='Year', 
                                     var_name='Education_Level', 
                                     value_name='Enrollment_Rate')

# %%
# Save melted enrollment trends
enrollment_melted.to_csv('enrollment_over_years.csv', index=False)

# %%
#Concat
#Combine raw and normalized
raw_cols = df[['Country', 'Year', 'GDP_per_capita']]
normalized_cols = df[['GDP_per_capita_winsorized', 'GDP_per_capita_log']]
combined = pd.concat([raw_cols, normalized_cols], axis=1)

# %%
# Save combined raw and normalized GDP data
combined.to_csv('gdp_combined_raw_normalized.csv', index=False)

# %%
#SQL

# %%
import sqlite3
import pandas as pd
import numpy as np

# Load CSV and compute GDP log in Python
df = pd.read_csv("global_edu_insights.csv")
df['GDP_per_capita_log'] = np.log(df['GDP_per_capita'])  # log base e (natural log)

# Connect to SQLite and write full DataFrame to DB
conn = sqlite3.connect("education_insights.db")
df.to_sql("global_edu_insights", conn, if_exists="replace", index=False)
cursor = conn.cursor()

# Step 1: Create gdp_combined table (no log needed in SQL now)
cursor.execute("""
CREATE TABLE IF NOT EXISTS gdp_combined AS
SELECT Country, Year, GDP_per_capita, GDP_per_capita_log
FROM global_edu_insights;
""")

# Step 2: Create region-level average GDP table
cursor.execute("""
CREATE TABLE IF NOT EXISTS region_avg AS
SELECT Region, ROUND(AVG(GDP_per_capita), 2) AS GDP_per_capita_winsorized
FROM global_edu_insights
GROUP BY Region;
""")

# Step 3: Melt enrollment columns into one table
cursor.execute("""
CREATE TABLE IF NOT EXISTS enrollment_melted AS
SELECT Country, Year, 'Primary' AS Education_Level, Primary_Enrollment AS Enrollment_Rate
FROM global_edu_insights
UNION ALL
SELECT Country, Year, 'Secondary', Secondary_Enrollment FROM global_edu_insights
UNION ALL
SELECT Country, Year, 'Tertiary', Tertiary_Enrollment FROM global_edu_insights;
""")

# Step 4: Create gdp_with_region by joining gdp_combined with region_avg using country → region mapping
cursor.execute("""
CREATE TABLE IF NOT EXISTS gdp_with_region AS
SELECT 
    g.Country, 
    g.Year, 
    g.GDP_per_capita, 
    g.GDP_per_capita_log, 
    gei.Region, 
    r.GDP_per_capita_winsorized AS Region_Avg_GDP
FROM gdp_combined g
LEFT JOIN global_edu_insights gei ON g.Country = gei.Country AND g.Year = gei.Year
LEFT JOIN region_avg r ON gei.Region = r.Region;
""")
conn.commit()

# Query 1: Average enrollment rate by year and level
query_avg_enrollment = """
SELECT Year, Education_Level, ROUND(AVG(Enrollment_Rate), 2) AS Avg_Enrollment
FROM enrollment_melted
GROUP BY Year, Education_Level;
"""
df_avg_enrollment = pd.read_sql_query(query_avg_enrollment, conn)

# Query 2: Top 10 countries by GDP per capita
query_top_gdp = """
SELECT Country, Year, GDP_per_capita
FROM gdp_combined
ORDER BY GDP_per_capita DESC
LIMIT 10;
"""
df_top_gdp = pd.read_sql_query(query_top_gdp, conn)

# Output results
print("Average Enrollment by Year and Level:")
print(df_avg_enrollment)

print("\n Top 10 Countries by GDP per Capita:")
print(df_top_gdp)

# Close the connection
conn.close()
# Out:
# Average Enrollment by Year and Level:
#     Year Education_Level  Avg_Enrollment
# 0   2015         Primary           94.74
# 1   2015       Secondary           74.90
# 2   2015        Tertiary           34.70
# 3   2016         Primary           94.40
# 4   2016       Secondary           74.78
# 5   2016        Tertiary           35.02
# 6   2017         Primary           94.50
# 7   2017       Secondary           74.67
# 8   2017        Tertiary           35.42
# 9   2018         Primary           94.84
# 10  2018       Secondary           74.79
# 11  2018        Tertiary           35.04
# 12  2019         Primary           94.79
# 13  2019       Secondary           74.87
# 14  2019        Tertiary           35.50
# 15  2020         Primary           94.59
# 16  2020       Secondary           74.93
# 17  2020        Tertiary           34.76
# 18  2021         Primary           94.69
# 19  2021       Secondary           74.65
# 20  2021        Tertiary           35.52
# 21  2022         Primary           94.47
# 22  2022       Secondary           74.75
# 23  2022        Tertiary           35.51
# 24  2023         Primary           94.44
# 25  2023       Secondary           75.17
# 26  2023        Tertiary           34.89
# 27  2024         Primary           94.52
# 28  2024       Secondary           75.11
# 29  2024        Tertiary           35.73
#
#  Top 10 Countries by GDP per Capita:
#        Country  Year  GDP_per_capita
# 0       Canada  2019        43844.73
# 1       Mexico  2015        43819.32
# 2       Mexico  2017        42614.87
# 3  South Korea  2019        42215.00
# 4    Australia  2024        42195.06
# 5    Indonesia  2017        41448.98
# 6       Turkey  2015        41272.95
# 7    Argentina  2021        41069.64
# 8       France  2022        39889.34
# 9        Japan  2022        39825.61
# C:\Users\malak\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df_avg_enrollment.to_csv("avg_enrollment_by_year.csv", index=False)
df_top_gdp.to_csv("top_gdp_countries.csv", index=False)

# %%
# Statistical summaries of GDP and Literacy
print(df[['GDP_per_capita', 'Literacy_Rate']].describe())

print("Median GDP:", df['GDP_per_capita'].median())
print("Variance of Literacy Rate:", df['Literacy_Rate'].var())
# Out:
#        GDP_per_capita  Literacy_Rate
# count    10000.000000   10000.000000
# mean     12926.395549      84.776670
# std       9125.852740       9.428202
# min     -27520.070000      50.000000
# 25%       7008.902500      78.300000
# 50%      13220.905000      85.100000
# 75%      19040.337500      91.700000
# max      43844.730000     100.000000
# Median GDP: 13220.905
# Variance of Literacy Rate: 88.89099181027962

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %%
sns.lineplot(data=df, x="Year", y="Literacy_Rate", hue="Region")
plt.title("Literacy Rate Trend by Region")
plt.show()

# %%
gdp_trend = df.groupby("Year")["GDP_per_capita"].mean().reset_index()

sns.lineplot(data=gdp_trend, x="Year", y="GDP_per_capita")
plt.title("Global Average GDP per Capita Over Time")
plt.show()

# %%
sns.histplot(df["GDP_per_capita"], kde=True)
plt.title("Distribution of GDP per Capita")
plt.show()

# %%
sns.scatterplot(data=df, x="GDP_per_capita", y="Literacy_Rate", hue="Region")
plt.title("GDP vs Literacy Rate by Region")
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Select features
features = df[['GDP_per_capita', 'Literacy_Rate', 'Unemployment_Rate']].dropna()

# Normalize
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(scaled_features)

# Plot clusters
sns.scatterplot(data=df, x='GDP_per_capita', y='Literacy_Rate', hue='Cluster', palette='Set2')
plt.title("Clusters of Countries Based on GDP and Literacy")
plt.show()

# %%
# Main cleaned dataset
df.to_csv("final_global_education_data.csv", index=False)

# Region averages
region_avg.to_csv("region_avg.csv", index=False)

# Enrollment melted
enrollment_melted.to_csv("enrollment_melted.csv", index=False)

# Optional: Clustering results
df[['Country', 'Year', 'GDP_per_capita', 'Literacy_Rate', 'Cluster']].to_csv("clusters.csv", index=False)
